# %%
import os
import sys

#  Set the working directory to the folder containing the top-level ultralytics package
os.chdir("/workspace")  # change to your workspace root where ultralytics folder exists
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /workspace

# %%
#  Add the top-level ultralytics folder to Python path
os.chdir("/workspace/ultralytics")
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /workspace/ultralytics

# %%
from ultralytics import YOLO
import time
import torch
from pathlib import Path
import pandas as pd

# === Parameters ===
dataset_yaml = "/workspace/datasets/KITTI/kitti.yml"
run_name = "yolov8n_base"
epochs_test = 2
imgsz = 1280
batch_size = 32
workers = 2
device = "cuda:0" if torch.cuda.is_available() else "cpu"
cache_images = "disk"
amp = True                # mixed precision
save_interval = 50         # save checkpoint every 2 epochs
patience = 40             # early stopping patience

# === Initialize YOLOv8n ===
model = YOLO("yolov8n.pt")

# === Start training ===
start_time = time.time()
results = model.train(
    data=dataset_yaml,
    epochs=epochs_test,
    imgsz=imgsz,
    batch=batch_size,
    workers=workers,
    device=device,
    cache=cache_images,
    name=run_name,
    save=True
)

training_time = time.time() - start_time
print(f"Training completed in {training_time/60:.2f} minutes")
# Out:
# Ultralytics 8.3.200 🚀 Python-3.10.12 torch-2.4.0a0+f70bd71a48.nv24.06 CUDA:0 (NVIDIA A100-SXM4-80GB, 81051MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=disk, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/workspace/datasets/KITTI/kitti.yml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=2, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1280, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov8n_base, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/workspace/ultralytics/runs/detect/yolov8n_base, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=7
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752677  ultralytics.nn.modules.head.Detect           [7, [64, 128, 256]]
# Model summary: 129 layers, 3,012,213 parameters, 3,012,197 gradients
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1977.7±88.3 MB/s, size: 728.7 KB)
# train: Scanning /workspace/datasets/KITTI/labels/train.cache... 5984 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 5984/5984 7.0Mit/s 0.0s0s
# train: Caching images (7.8GB Disk): 100% ━━━━━━━━━━━━ 5984/5984 35.5Kit/s 0.2s8s
# val: Fast image access ✅ (ping: 0.1±0.1 ms, read: 1429.8±704.4 MB/s, size: 814.7 KB)
# val: Scanning /workspace/datasets/KITTI/labels/val.cache... 1497 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1497/1497 1.9Mit/s 0.0ss
# val: Caching images (1.9GB Disk): 100% ━━━━━━━━━━━━ 1497/1497 38.6Kit/s 0.0s
# Plotting labels to /workspace/ultralytics/runs/detect/yolov8n_base/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000909, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 1280 train, 1280 val
# Using 2 dataloader workers
# Logging results to /workspace/ultralytics/runs/detect/yolov8n_base
# Starting training for 2 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/2        22G      1.237      2.146       1.14        365       1280: 100% ━━━━━━━━━━━━ 187/187 1.6it/s 1:550.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 4.7it/s 5.1s0.2s
#                    all       1497       7772      0.587      0.523       0.54      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/2        22G      1.067      1.233      1.064        267       1280: 100% ━━━━━━━━━━━━ 187/187 1.9it/s 1:410.4sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 5.6it/s 4.3s0.2s
#                    all       1497       7772      0.673      0.659      0.682      0.445
#
# 2 epochs completed in 0.063 hours.
# Optimizer stripped from /workspace/ultralytics/runs/detect/yolov8n_base/weights/last.pt, 6.3MB
# Optimizer stripped from /workspace/ultralytics/runs/detect/yolov8n_base/weights/best.pt, 6.3MB
#
# Validating /workspace/ultralytics/runs/detect/yolov8n_base/weights/best.pt...
# Ultralytics 8.3.200 🚀 Python-3.10.12 torch-2.4.0a0+f70bd71a48.nv24.06 CUDA:0 (NVIDIA A100-SXM4-80GB, 81051MiB)
# Model summary (fused): 72 layers, 3,007,013 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 4.3it/s 5.6s0.2s
#                    all       1497       7772      0.671       0.66      0.682      0.445
#                    Car       1333       5680      0.835      0.898      0.936      0.693
#                    Van        425        563      0.728      0.606      0.691      0.502
#                  Truck        190        198      0.698      0.641      0.706      0.552
#             Pedestrian        357        896      0.738      0.676      0.725      0.386
#         Person_sitting         13         30       0.41      0.367      0.331      0.146
#                Cyclist        222        306      0.698      0.619      0.698      0.401
#                   Tram         76         99      0.592      0.818      0.685      0.434
# Speed: 0.1ms preprocess, 0.5ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /workspace/ultralytics/runs/detect/yolov8n_base
# Training completed in 4.05 minutes

# %%
from ultralytics import YOLO
import time
import torch

# === Parameters ===
dataset_yaml = "datasets/KITTI/kitti.yml"
run_name = "yolov8n_base_sdgpat40"
epochs = 250                # max epochs; early stopping may stop earlier
imgsz = 1280              # research-level resolution
batch_size = 32           # adjust according to VRAM
workers = 2               # safer for shared memory
device = "cuda:0" if torch.cuda.is_available() else "cpu"
cache_images = "disk"
amp = True                # mixed precision
save_interval = 50         # save checkpoint every 2 epochs
patience = 40             # early stopping patience

# === Initialize YOLOv8n ===
model = YOLO("yolov8n.pt")  # pre-trained weights


# === Start training ===
start_time = time.time()
print(f"Starting training for {epochs} epochs...\n")

results = model.train(
    data=dataset_yaml,
    epochs=epochs,
    imgsz=imgsz,
    batch=batch_size,
    workers=workers,
    device=device,
    cache=cache_images,
    name=run_name,
    save=True,
    amp=amp,
    patience=patience,
    save_period=save_interval
)

total_time = time.time() - start_time
print(f"\nTraining completed in {total_time/3600:.2f} hours")
# Out:
# Starting training for 250 epochs...
#
# Ultralytics 8.3.200 🚀 Python-3.10.12 torch-2.4.0a0+f70bd71a48.nv24.06 CUDA:0 (NVIDIA A100-SXM4-80GB, 81051MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=disk, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=datasets/KITTI/kitti.yml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=250, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1280, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov8n_base2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=40, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/workspace/ultralytics/runs/detect/yolov8n_base2, save_frames=False, save_json=False, save_period=50, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=7
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752677  ultralytics.nn.modules.head.Detect           [7, [64, 128, 256]]
# Model summary: 129 layers, 3,012,213 parameters, 3,012,197 gradients
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.1±0.1 ms, read: 1709.5±205.3 MB/s, size: 728.7 KB)
# train: Scanning /workspace/datasets/KITTI/labels/train.cache... 5984 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 5984/5984 7.6Mit/s 0.0s0s
# train: Caching images (7.8GB Disk): 100% ━━━━━━━━━━━━ 5984/5984 31.6Kit/s 0.2ss
# val: Fast image access ✅ (ping: 0.2±0.1 ms, read: 1672.4±624.7 MB/s, size: 814.7 KB)
# val: Scanning /workspace/datasets/KITTI/labels/val.cache... 1497 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1497/1497 980.0Kit/s 0.0s
# val: Caching images (1.9GB Disk): 100% ━━━━━━━━━━━━ 1497/1497 40.0Kit/s 0.0s
# Plotting labels to /workspace/ultralytics/runs/detect/yolov8n_base2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 1280 train, 1280 val
# Using 2 dataloader workers
# Logging results to /workspace/ultralytics/runs/detect/yolov8n_base2
# Starting training for 250 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/250        22G      1.261      2.379      1.162        365       1280: 100% ━━━━━━━━━━━━ 187/187 1.7it/s 1:520.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 4.4it/s 5.4s0.2s
#                    all       1497       7772      0.609      0.438       0.44      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/250        22G      1.136      1.444      1.096        267       1280: 100% ━━━━━━━━━━━━ 187/187 1.8it/s 1:410.5sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 5.1it/s 4.7s0.2s
#                    all       1497       7772      0.708      0.519      0.569       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/250        22G      1.134      1.244      1.102        335       1280: 100% ━━━━━━━━━━━━ 187/187 1.8it/s 1:420.4sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 5.7it/s 4.2s0.2s
#                    all       1497       7772      0.588      0.479      0.521      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/250        22G      1.132      1.066      1.109        372       1280: 100% ━━━━━━━━━━━━ 187/187 1.9it/s 1:410.4sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 5.7it/s 4.2s0.2s
#                    all       1497       7772       0.53      0.582      0.561      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/250        22G      1.086     0.9215      1.097        366       1280: 100% ━━━━━━━━━━━━ 187/187 1.8it/s 1:420.4sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 5.8it/s 4.1s0.2s
#                    all       1497       7772       0.66      0.548      0.643      0.399
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/250        22G      1.055     0.8558      1.083        342       1280: 100% ━━━━━━━━━━━━ 187/187 1.8it/s 1:420.4sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 5.9it/s 4.1s0.2s
#                    all       1497       7772      0.675      0.627      0.683      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/250        22G      1.034      0.809      1.076        369       1280: 100% ━━━━━━━━━━━━ 187/187 1.8it/s 1:420.5sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 5.8it/s 4.1s0.2s
#                    all       1497       7772      0
0.76
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     144/250        22G     0.5958     0.3756     0.8814        318       1280: 89% ━━━━━━━━━━╸─ 167/187 1.9it/s 1:32<10.7ss

# %%
import sys
from pathlib import Path
import torch
import time
from ultralytics import YOLO  # Use YOLOv8's interface

weights = "runs/detect/yolov8n_base/weights/best.pt"
dataset_yaml = "/workspace/datasets/KITTI/kitti.yml"
results_dir = "/workspace/yolov8n_base_sdgpat40_val"

# ------------------- Device -------------------
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# ------------------- Load model -------------------
model = YOLO(weights)  # Load the model using YOLOv8
params = sum(p.numel() for p in model.model.parameters())
params_mb = params * 4 / (1024**2)  # float32 -> 4 bytes
model_size_mb = Path(weights).stat().st_size / 1024**2  # file size in MB

print(f"Model size (file): {model_size_mb:.2f} MB")
print(f"Model parameters: {params_mb:.2f} MB")

# ------------------- FPS Measurement -------------------
dummy_input = torch.randn(1, 3, 1280, 1280).to(device) / 255.0  # Normalize the dummy input
# Warm-up
for _ in range(5):
    _ = model(dummy_input)  # Use the model directly for inference

n_runs = 50
start_time = time.time()
for _ in range(n_runs):
    _ = model(dummy_input)  # Use the model directly for inference
end_time = time.time()

fps = n_runs / (end_time - start_time)
print(f"Inference FPS (1280x1280): {fps:.2f}")

# ------------------- Run Validation -------------------
print("\nRunning YOLOv8 validation...")
start_val_time = time.time()
model.val(
    data=dataset_yaml,  # Validation dataset
    imgsz=1280,          # Image size
    batch=64,            # Corrected batch size argument
    device=device,       # Device
    project=results_dir, # Results directory
    name="eval_metrics", # Name for saved results
    save_json=True,      # Save results as JSON
    exist_ok=True,       # Overwrite if results directory exists
    verbose=True         # Show verbose output
)
end_val_time = time.time()

val_time = end_val_time - start_val_time
print(f"Validation time: {val_time:.2f} seconds")
print(f"Validation results saved to {results_dir}")
# Out:
# Model size (file): 6.00 MB
# Model parameters: 11.49 MB
#
# 0: 1280x1280 (no detections), 5.7ms
# Speed: 0.0ms preprocess, 5.7ms inference, 18.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 5.6ms
# Speed: 0.0ms preprocess, 5.6ms inference, 3.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 3.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 5.1ms
# Speed: 0.0ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.9ms
# Speed: 0.0ms preprocess, 4.9ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.7ms
# Speed: 0.0ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 4.8ms
# Speed: 0.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
# Inference FPS (1280x1280): 137.52
#
# Running YOLOv8 validation...
# val: Fast image access ✅ (ping: 0.2±0.1 ms, read: 1638.6±480.5 MB/s, size: 809.9 KB)
# val: Scanning /workspace/datasets/KITTI/labels/val.cache... 1497 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1497/1497 2.9Mit/s 0.0s0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 1.6it/s 15.2s0.2s
#                    all       1497       7772       0.93      0.901      0.939      0.767
#                    Car       1333       5680      0.964       0.96      0.987      0.885
#                    Van        425        563      0.959       0.96      0.981       0.87
#                  Truck        190        198      0.966      0.929      0.969       0.89
#             Pedestrian        357        896      0.951      0.788      0.905      0.572
#         Person_sitting         13         30      0.806      0.833      0.841      0.582
#                Cyclist        222        306      0.922      0.888      0.945      0.739
#                   Tram         76         99       0.94      0.944      0.946      0.829
# Speed: 1.3ms preprocess, 0.8ms inference, 0.0ms loss, 1.5ms postprocess per image
# Saving /workspace/yolov8n_base/eval_metrics/predictions.json...
# Results saved to /workspace/yolov8n_base/eval_metrics
# Validation time: 19.97 seconds
# Validation results saved to /workspace/yolov8n_base

# %%
import shutil

# Specify the folder path and the destination zip file path
folder_path = 'runs/detect/yolov8n_base_sdgpat40'
zip_file_path = 'runs/detect/yolov8n_base_sdgpat40.zip'

# Create a zip file from the folder
shutil.make_archive(zip_file_path.replace('.zip', ''), 'zip', folder_path)
# Out:
# '/workspace/ultralytics/runs/detect/yolov8n_base_sdgpat40.zip'

# %%
import shutil

# Specify the folder path and the destination zip file path
folder_path = '/workspace/vals/yolov8n_base_sdgpat40_val'
zip_file_path = '/workspace/vals/yolov8n_base_sdgpat40_val.zip'

# Create a zip file from the folder
shutil.make_archive(zip_file_path.replace('.zip', ''), 'zip', folder_path)
# Out:
# '/workspace/vals/yolov8n_base_sdgpat40_val.zip'
