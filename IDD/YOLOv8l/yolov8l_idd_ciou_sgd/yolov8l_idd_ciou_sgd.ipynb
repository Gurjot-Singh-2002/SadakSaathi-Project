# %%
pwd
# Out:
# '/workspace'

# %%
import os
import sys

#  Set the working directory to the folder containing the top-level ultralytics package
os.chdir("/workspace")  # change to your workspace root where ultralytics folder exists
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /workspace

# %%
#  Add the top-level ultralytics folder to Python path
os.chdir("/workspace/ultralytics")
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /workspace/ultralytics

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.234 🚀 Python-3.12.3 torch-2.6.0a0+df5bbc09d1.nv24.12 CUDA:0 (NVIDIA H100 80GB HBM3 MIG 3g.40gb, 40320MiB)
# Setup complete ✅ (224 CPUs, 2015.6 GB RAM, 621.6/3515.6 GB disk)

# %%
from ultralytics import YOLO

# -------------------------------
# Load YAML (with original SPPF)
# -------------------------------
model = YOLO('yolov8.yaml')
print("Original model loaded ")
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='l'.
# Original model loaded

# %%
import ultralytics
print(ultralytics.__file__)
# Out:
# /workspace/ultralytics/ultralytics/__init__.py

# %%
from ultralytics.models.yolo.model import YOLO

# Load your YOLOv8 model
model = YOLO("ultralytics/cfg/models/v8/yolov8.yaml")

# Print the full architecture
print(model.model)   # model.model contains the actual PyTorch nn.Module
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='l'.
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0-2): 3 x Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (3): Conv(
#       (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (4): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0-5): 6 x Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (5): Conv(
#       (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (6): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0-5): 6 x Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (7): Conv(
#       (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (8): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(1280, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0-2): 3 x Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (9): SPPF(
#       (cv1): Conv(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#     )
#     (10): Upsample(scale_factor=2.0, mode='nearest')
#     (11): Concat()
#     (12): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(1280, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0-2): 3 x Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (13): Upsample(scale_factor=2.0, mode='nearest')
#     (14): Concat()
#     (15): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(640, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0-2): 3 x Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (16): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (17): Concat()
#     (18): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(1280, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0-2): 3 x Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (19): Conv(
#       (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (20): Concat()
#     (21): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(1280, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0-2): 3 x Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (22): Detect(
#       (cv2): ModuleList(
#         (0): Sequential(
#           (0): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1-2): 2 x Sequential(
#           (0): Conv(
#             (conv): Conv2d(512, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (cv3): ModuleList(
#         (0): Sequential(
#           (0): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(256, 11, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1-2): 2 x Sequential(
#           (0): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(256, 11, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (dfl): DFL(
#         (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#   )
# )

# %%
from ultralytics.nn import tasks
from ultralytics.models.yolo.model import YOLO

model = YOLO("ultralytics/cfg/models/v8/yolov8.yaml")
model.info()
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='l'.
# YOLOv8 summary: 209 layers, 43,638,321 parameters, 43,638,305 gradients, 165.4 GFLOPs
# (209, 43638321, 43638305, 165.4460928)

# %%
from ultralytics import YOLO
import time
import torch

# === Parameters ===
dataset_yaml = "/workspace/datasets/IDD_YOLO/idd.yaml"
run_name = "try"
epochs = 1                
imgsz = 640              
batch_size = 32
workers = 4
device = "cuda:0" if torch.cuda.is_available() else "cpu"
cache_images = "disk"
amp = True                
save_interval = 40        
patience = 20             

# === Initialize YOLOv8n ===
model = YOLO("yolov8l.pt")

# === Start training ===
start_time = time.time()
print(f"Starting training for {epochs} epochs...\n")

results = model.train(
    data=dataset_yaml,
    epochs=epochs,
    imgsz=imgsz,
    batch=batch_size,
    workers=workers,
    device=device,
    cache=cache_images,
    name=run_name,
    save=True,
    amp=amp,
    patience=patience,
    save_period=save_interval
)

total_time = time.time() - start_time
print(f"\nTraining completed in {total_time/3600:.2f} hours")
# Out:
# Starting training for 1 epochs...
#
# New https://pypi.org/project/ultralytics/8.3.235 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.234 🚀 Python-3.12.3 torch-2.6.0a0+df5bbc09d1.nv24.12 CUDA:0 (NVIDIA H100 80GB HBM3 MIG 3g.40gb, 40320MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=disk, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/workspace/datasets/IDD_YOLO/idd.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=1, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8l.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=try, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/workspace/ultralytics/runs/detect/try, save_frames=False, save_json=False, save_period=40, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  3   4461568  ultralytics.nn.modules.block.C2f             [512, 512, 3, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   4723712  ultralytics.nn.modules.block.C2f             [1024, 512, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1247744  ultralytics.nn.modules.block.C2f             [768, 256, 3]
#  16                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   4592640  ultralytics.nn.modules.block.C2f             [768, 512, 3]
#  19                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   4723712  ultralytics.nn.modules.block.C2f             [1024, 512, 3]
#  22        [15, 18, 21]  1   5591281  ultralytics.nn.modules.head.Detect           [11, [256, 512, 512]]
# Model summary: 209 layers, 43,638,321 parameters, 43,638,305 gradients, 165.4 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1632.9±118.5 MB/s, size: 500.4 KB)
#
# train: /workspace/datasets/IDD_YOLO/images/train/highquality_16k_BLR-2018-06-22-05-05-26_part_45_0001125.jpg: 1 duplicate labels removed
# train: /workspace/datasets/IDD_YOLO/images/train/highquality_16k_HYD-2018-06-15_11-55-11_frontNear_left_0004560.jpg: 1 duplicate labels removed
# WARNING ⚠️ train: 270.6GB disk space required, with 50% safety margin but only 61.4/285.0GB free, not caching images to disk
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 783.3±285.9 MB/s, size: 512.9 KB)
#
# val: /workspace/datasets/IDD_YOLO/images/val/highquality_16k_HYD-2018-08-24_13-02-50_0004247.jpg: 1 duplicate labels removed
# val: /workspace/datasets/IDD_YOLO/images/val/highquality_16k_HYD-2018-08-24_13-22-50_0007776.jpg: 1 duplicate labels removed
# val: /workspace/datasets/IDD_YOLO/images/val/highquality_16k_HYD-2018-08-24_13-22-50_0008384.jpg: 1 duplicate labels removed
# WARNING ⚠️ val: 83.6GB disk space required, with 50% safety margin but only 61.4/285.0GB free, not caching images to disk
# Plotting labels to /workspace/ultralytics/runs/detect/try/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000667, momentum=0.9) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /workspace/ultralytics/runs/detect/try
# Starting training for 1 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.606      0.361      0.391      0.245
#
# 1 epochs completed in 0.083 hours.
# Optimizer stripped from /workspace/ultralytics/runs/detect/try/weights/last.pt, 87.6MB
# Optimizer stripped from /workspace/ultralytics/runs/detect/try/weights/best.pt, 87.6MB
#
# Validating /workspace/ultralytics/runs/detect/try/weights/best.pt...
# Ultralytics 8.3.234 🚀 Python-3.12.3 torch-2.6.0a0+df5bbc09d1.nv24.12 CUDA:0 (NVIDIA H100 80GB HBM3 MIG 3g.40gb, 40320MiB)
# Model summary (fused): 112 layers, 43,615,089 parameters, 0 gradients, 164.9 GFLOPs
#
#                    all      10225     119936      0.604      0.362      0.391      0.245
#                 person       5047      18078      0.523      0.456      0.446      0.248
#                  rider       6130      24517      0.718      0.429      0.487      0.269
#                    car       6592      24843      0.865      0.483      0.592      0.409
#                  truck       3933       7077      0.466      0.474      0.436      0.301
#                    bus       2803       4915       0.73      0.454      0.521      0.387
#             motorcycle       7149      25489      0.728      0.498       0.56      0.306
#                bicycle        484        569      0.452       0.26      0.233      0.137
#           autorickshaw       3411       7782       0.65      0.553      0.589      0.412
#                 animal        398       1460      0.245      0.138      0.101     0.0563
#          traffic light        410        919      0.746      0.032      0.124     0.0535
#           traffic sign       2342       4287      0.521        0.2      0.217      0.116
# Speed: 0.0ms preprocess, 1.4ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /workspace/ultralytics/runs/detect/try
#
# Training completed in 0.10 hours

# %%
from ultralytics import YOLO
import time
import torch

# === Parameters ===
dataset_yaml = "/workspace/datasets/IDD_YOLO/idd.yaml"
run_name = "yolov8l_idd_ciou_sgd"
epochs = 150                
imgsz = 640              
batch_size = 32           
workers = 4               
device = "cuda:0" if torch.cuda.is_available() else "cpu"
cache_images = "disk"
amp = True                
save_interval = 40        
patience = 20             

# === Initialize YOLOv8n ===
model = YOLO("yolov8l.pt")

# === Start training ===
start_time = time.time()
print(f"Starting training for {epochs} epochs...\n")

results = model.train(
    data=dataset_yaml,
    epochs=epochs,
    imgsz=imgsz,
    batch=batch_size,
    workers=workers,
    device=device,
    cache=cache_images,
    name=run_name,
    save=True,
    amp=amp,
    patience=patience,
    save_period=save_interval
)

total_time = time.time() - start_time
print(f"\nTraining completed in {total_time/3600:.2f} hours")
# Out:
# Starting training for 150 epochs...
#
# New https://pypi.org/project/ultralytics/8.3.235 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.234 🚀 Python-3.12.3 torch-2.6.0a0+df5bbc09d1.nv24.12 CUDA:0 (NVIDIA H100 80GB HBM3 MIG 3g.40gb, 40320MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=disk, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/workspace/datasets/IDD_YOLO/idd.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=150, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8l.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov8l_idd_ciou_sgd, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/workspace/ultralytics/runs/detect/yolov8l_idd_ciou_sgd, save_frames=False, save_json=False, save_period=40, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  3   4461568  ultralytics.nn.modules.block.C2f             [512, 512, 3, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   4723712  ultralytics.nn.modules.block.C2f             [1024, 512, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1247744  ultralytics.nn.modules.block.C2f             [768, 256, 3]
#  16                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   4592640  ultralytics.nn.modules.block.C2f             [768, 512, 3]
#  19                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   4723712  ultralytics.nn.modules.block.C2f             [1024, 512, 3]
#  22        [15, 18, 21]  1   5591281  ultralytics.nn.modules.head.Detect           [11, [256, 512, 512]]
# Model summary: 209 layers, 43,638,321 parameters, 43,638,305 gradients, 165.4 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1400.1±298.2 MB/s, size: 512.7 KB)
#
# train: /workspace/datasets/IDD_YOLO/images/train/highquality_16k_BLR-2018-06-22-05-05-26_part_45_0001125.jpg: 1 duplicate labels removed
# train: /workspace/datasets/IDD_YOLO/images/train/highquality_16k_HYD-2018-06-15_11-55-11_frontNear_left_0004560.jpg: 1 duplicate labels removed
# WARNING ⚠️ train: 266.9GB disk space required, with 50% safety margin but only 61.4/285.0GB free, not caching images to disk
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 833.7±184.6 MB/s, size: 416.2 KB)
#
# val: /workspace/datasets/IDD_YOLO/images/val/highquality_16k_HYD-2018-08-24_13-02-50_0004247.jpg: 1 duplicate labels removed
# val: /workspace/datasets/IDD_YOLO/images/val/highquality_16k_HYD-2018-08-24_13-22-50_0007776.jpg: 1 duplicate labels removed
# val: /workspace/datasets/IDD_YOLO/images/val/highquality_16k_HYD-2018-08-24_13-22-50_0008384.jpg: 1 duplicate labels removed
# WARNING ⚠️ val: 82.4GB disk space required, with 50% safety margin but only 61.4/285.0GB free, not caching images to disk
# Plotting labels to /workspace/ultralytics/runs/detect/yolov8l_idd_ciou_sgd/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /workspace/ultralytics/runs/detect/yolov8l_idd_ciou_sgd
# Starting training for 150 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.672      0.427      0.468      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.673      0.411      0.456      0.292
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.636      0.365        0.4       0.25
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936       0.68      0.369      0.418      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.696      0.407      0.454      0.291
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.691      0.423      0.473      0.303
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.708      0.432      0.481      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.707      0.438      0.492      0.319
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.735      0.448      0.504      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.716      0.456      0.511      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.738      0.465      0.523       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.732      0.469      0.527      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.749      0.474      0.532      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.739      0.479      0.535       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.742      0.483      0.542      0.354
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.746      0.489      0.544      0.357
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.761      0.489      0.548       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.756      0.495      0.555      0.364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.765      0.494      0.554      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.764      0.504       0.56      0.369
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.765      0.502      0.562      0.371
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936       0.77      0.504      0.565      0.372
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.766       0.51      0.567      0.374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.763      0.513      0.569      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.769      0.513      0.571      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.774      0.511      0.573      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936       0.77      0.512      0.575      0.379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.774      0.511      0.576      0.379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.769      0.515      0.577       0.38
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.767      0.519      0.578      0.381
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.771      0.519      0.579      0.381
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.772       0.52      0.579      0.381
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.775       0.52      0.579      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.776       0.52       0.58      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.774       0.52       0.58      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936       0.77      0.521      0.581      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.771      0.523      0.581      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936       0.77      0.524      0.581      0.384
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.773      0.523      0.582      0.384
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.768      0.525      0.582      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.771      0.525      0.583      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.769      0.526      0.583      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.769      0.525      0.583      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.772      0.525      0.584      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.769      0.526      0.584      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.773      0.525      0.585      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.774      0.525      0.585      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.776      0.524      0.586      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.777      0.524      0.586      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.775      0.526      0.586      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.775      0.527      0.587      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.776      0.527      0.587      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.778      0.526      0.588      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.778      0.527      0.588      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.779      0.527      0.588      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.779      0.527      0.589      0.389
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.777      0.529      0.589      0.389
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.779      0.528       0.59      0.389
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.781      0.527       0.59       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.784      0.528       0.59       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.783      0.528      0.591       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.782      0.529      0.591       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.782      0.528      0.591       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.777       0.53      0.591       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.777      0.531      0.592      0.391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.775      0.532      0.592      0.391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.778      0.531      0.592      0.391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.778      0.531      0.592      0.391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.779      0.531      0.592      0.391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.779      0.532      0.593      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.776      0.532      0.593      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.777      0.532      0.593      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.776      0.532      0.593      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.777      0.533      0.594      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.777      0.534      0.594      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.776      0.535      0.594      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.778      0.535      0.595      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936       0.78      0.535      0.595      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.779      0.535      0.595      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.779      0.535      0.595      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.778      0.536      0.595      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.774      0.537      0.596      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.777      0.537      0.596      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.775      0.538      0.596      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.775      0.538      0.596      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#
#                    all      10225     119936      0.776      0.538      0.597      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.774      0.539      0.597      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.773       0.54      0.597      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.773       0.54      0.597      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.773       0.54      0.597      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.773       0.54      0.597      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.773       0.54      0.597      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.772       0.54      0.597      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.773      0.539      0.597      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.775      0.539      0.598      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.774       0.54      0.598      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.774       0.54      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.773      0.541      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.776       0.54      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.775      0.541      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.775       0.54      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.774       0.54      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.773      0.541      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.775       0.54      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.774       0.54      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.775      0.539      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.777      0.539      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.776      0.538      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.777      0.538        0.6      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936       0.78      0.537        0.6      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936       0.78      0.537      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.779      0.537        0.6      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.783      0.536      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.782      0.536      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936       0.78      0.537      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936       0.78      0.538      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.781      0.537        0.6      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.779      0.539        0.6      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936       0.78      0.538        0.6      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.781      0.538      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.777      0.538        0.6      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.775      0.538      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.775      0.538      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.773      0.539      0.599      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.777      0.537      0.599      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#
#                    all      10225     119936      0.779      0.536      0.599      0.394
# EarlyStopping: Training stopped early as no improvement observed in last 20 epochs. Best results observed at epoch 107, best model saved as best.pt.
# To update EarlyStopping(patience=20) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 127 epochs completed in 9.947 hours.
# Optimizer stripped from /workspace/ultralytics/runs/detect/yolov8l_idd_ciou_sgd/weights/last.pt, 87.7MB
# Optimizer stripped from /workspace/ultralytics/runs/detect/yolov8l_idd_ciou_sgd/weights/best.pt, 87.7MB
#
# Validating /workspace/ultralytics/runs/detect/yolov8l_idd_ciou_sgd/weights/best.pt...
# Ultralytics 8.3.234 🚀 Python-3.12.3 torch-2.6.0a0+df5bbc09d1.nv24.12 CUDA:0 (NVIDIA H100 80GB HBM3 MIG 3g.40gb, 40320MiB)
# Model summary (fused): 112 layers, 43,615,089 parameters, 0 gradients, 164.9 GFLOPs
#
#                    all      10225     119936      0.775      0.539      0.599      0.395
#                 person       5047      18078      0.795      0.525      0.603      0.355
#                  rider       6130      24517      0.839       0.55      0.628      0.385
#                    car       6592      24843      0.855       0.66      0.731      0.529
#                  truck       3933       7077      0.749      0.657      0.705       0.52
#                    bus       2803       4915      0.832      0.707      0.772      0.598
#             motorcycle       7149      25489      0.826      0.658      0.715      0.455
#                bicycle        484        569      0.727      0.529      0.547      0.343
#           autorickshaw       3411       7782      0.851      0.702       0.77      0.567
#                 animal        398       1460      0.676      0.262      0.329      0.172
#          traffic light        410        919      0.708      0.298      0.367      0.178
#           traffic sign       2342       4287      0.671      0.379      0.427      0.247
# Speed: 0.0ms preprocess, 1.4ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /workspace/ultralytics/runs/detect/yolov8l_idd_ciou_sgd
#
# Training completed in 9.96 hours

# %%
from ultralytics import YOLO
import torch
import time

# ------------------- Paths -------------------
weights = "/workspace/ultralytics/runs/detect/yolov8l_idd_ciou_sgd/weights/best.pt"
dataset_yaml = "/workspace/datasets/IDD_YOLO/idd.yaml"
results_dir = "/workspace/idd_validation"

device = "cuda:0" if torch.cuda.is_available() else "cpu"

# ------------------- Load model -------------------
model = YOLO(weights)

# ------------------- Run Validation -------------------
print("Running validation...")

start = time.time()

model.val(
    data=dataset_yaml,
    imgsz=640,
    batch=64,
    device=device,
    project=results_dir,
    name="idd_evalv8l_ciou_sgd",
    save_json=True,
    exist_ok=True,
    verbose=True
)

end = time.time()
print(f"\nValidation completed in {end - start:.2f} seconds")
print(f"Results saved in {results_dir}/idd_eval/")
# Out:
# Running validation...
# Ultralytics 8.3.234 🚀 Python-3.12.3 torch-2.6.0a0+df5bbc09d1.nv24.12 CUDA:0 (NVIDIA H100 80GB HBM3 MIG 3g.40gb, 40320MiB)
# Model summary (fused): 112 layers, 43,615,089 parameters, 0 gradients, 164.9 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1196.6±518.6 MB/s, size: 504.8 KB)
#
# val: /workspace/datasets/IDD_YOLO/images/val/highquality_16k_HYD-2018-08-24_13-02-50_0004247.jpg: 1 duplicate labels removed
# val: /workspace/datasets/IDD_YOLO/images/val/highquality_16k_HYD-2018-08-24_13-22-50_0007776.jpg: 1 duplicate labels removed
# val: /workspace/datasets/IDD_YOLO/images/val/highquality_16k_HYD-2018-08-24_13-22-50_0008384.jpg: 1 duplicate labels removed
#
#                    all      10225     119936      0.776      0.539        0.6      0.396
#                 person       5047      18078      0.795      0.525      0.604      0.356
#                  rider       6130      24517      0.838       0.55      0.627      0.386
#                    car       6592      24843      0.854       0.66      0.731      0.529
#                  truck       3933       7077      0.749      0.657      0.704       0.52
#                    bus       2803       4915      0.832      0.707      0.772      0.598
#             motorcycle       7149      25489      0.827      0.659      0.715      0.456
#                bicycle        484        569      0.726      0.527      0.545      0.342
#           autorickshaw       3411       7782       0.85      0.702       0.77      0.568
#                 animal        398       1460      0.678      0.263       0.33      0.173
#          traffic light        410        919      0.713        0.3      0.372      0.179
#           traffic sign       2342       4287      0.673       0.38      0.429      0.248
# Speed: 0.3ms preprocess, 2.1ms inference, 0.0ms loss, 0.3ms postprocess per image
# Saving /workspace/idd_validation/idd_evalv8l_ciou_sgd/predictions.json...
# Results saved to /workspace/idd_validation/idd_evalv8l_ciou_sgd
#
# Validation completed in 58.03 seconds
# Results saved in /workspace/idd_validation/idd_eval/

# %%
from ultralytics import YOLO

# Try loading and running inference with the trained model
model = YOLO("/workspace/ultralytics/runs/detect/yolov8l_idd_ciou_sgd/weights/best.pt")  # path to your trained model
results = model.predict("/workspace/0000240.jpg")  # use any sample image
results[0].show()
# Out:
# image 1/1 /workspace/0000240.jpg: 384x640 1 person, 5 cars, 1 traffic sign, 42.9ms
# Speed: 1.6ms preprocess, 42.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=1920x1080>

# %%
import numpy as np
import pandas as pd

class_names = [
    "person", "rider", "car", "truck", "bus",
    "motorcycle", "bicycle", "autorickshaw",
    "animal", "traffic light", "traffic sign"
]

conf_matrix = np.array([
    [9530,385,115,2,37,1,1,8,0,2,1825],
    [484,13466,87,2,0,135,2,18,1,1,1863],
    [13,42,16530,119,86,34,0,121,0,2,2221],
    [0,4,138,4542,198,5,0,195,0,1,1114],
    [2,0,88,202,3437,0,0,6,0,3,435],
    [124,177,135,5,1,16844,45,4,11,1,2909],
    [1,3,1,0,9,32,296,0,1,0,69],
    [4,12,114,142,10,5,0,5445,2,0,673],
    [3,0,0,0,0,0,0,0,396,0,164],
    [0,0,0,0,0,0,0,0,0,289,91],
    [1,1,3,2,0,0,0,0,0,5,1645]
])

per_class_precision = [0.795,0.838,0.854,0.749,0.832,0.827,0.726,0.850,0.678,0.713,0.673]
per_class_recall    = [0.525,0.550,0.660,0.657,0.707,0.659,0.527,0.702,0.263,0.300,0.380]
per_class_map50     = [0.604,0.627,0.731,0.704,0.772,0.715,0.545,0.770,0.330,0.372,0.429]
per_class_map5095   = [0.356,0.386,0.529,0.520,0.598,0.456,0.342,0.568,0.173,0.179,0.248]

metrics_data = []
total_samples = np.sum(conf_matrix)

for i, cname in enumerate(class_names):
    TP = conf_matrix[i, i]
    FP = np.sum(conf_matrix[i, :]) - TP
    FN = np.sum(conf_matrix[:, i]) - TP
    TN = total_samples - (TP + FP + FN)

    P = per_class_precision[i]
    R = per_class_recall[i]
    F1 = 2 * P * R / (P + R) if (P + R) else 0

    metrics_data.append({
        "Class": cname,
        "TP": TP,
        "FP": FP,
        "FN": FN,
        "TN": TN,
        "Precision": round(P,4),
        "Recall": round(R,4),
        "F1 Score": round(F1,4),
        "Accuracy": round((TP + TN) / total_samples,4),
        "FPR": round(FP / (FP + TN),4),
        "FNR": round(FN / (FN + TP),4),
        "mAP@0.5": per_class_map50[i],
        "mAP@0.5:0.95": per_class_map5095[i]
    })

# -----------------------------
# OVERALL ROW
# -----------------------------
overall = {
    "Class": "Overall",
    "TP": sum(r["TP"] for r in metrics_data),
    "FP": sum(r["FP"] for r in metrics_data),
    "FN": sum(r["FN"] for r in metrics_data),
    "TN": sum(r["TN"] for r in metrics_data),
    "Precision": round(np.mean([r["Precision"] for r in metrics_data]),4),
    "Recall": round(np.mean([r["Recall"] for r in metrics_data]),4),
    "F1 Score": round(np.mean([r["F1 Score"] for r in metrics_data]),4),
    "Accuracy": round(np.mean([r["Accuracy"] for r in metrics_data]),4),
    "FPR": round(np.mean([r["FPR"] for r in metrics_data]),4),
    "FNR": round(np.mean([r["FNR"] for r in metrics_data]),4),
    "mAP@0.5": round(np.mean(per_class_map50),4),
    "mAP@0.5:0.95": round(np.mean(per_class_map5095),4)
}

metrics_data.append(overall)

df = pd.DataFrame(metrics_data)
df.to_csv("idd_metrics_v8lciousgd.csv", index=False)
print(df)
# Out:
#             Class     TP     FP     FN      TN  Precision  Recall  F1 Score  \
# 0          person   9530   2376    632   74640     0.7950  0.5250    0.6324
# 1           rider  13466   2593    624   70495     0.8380  0.5500    0.6641
# 2             car  16530   2638    681   67329     0.8540  0.6600    0.7446
# 3           truck   4542   1655    474   80507     0.7490  0.6570    0.7000
# 4             bus   3437    736    341   82664     0.8320  0.7070    0.7644
# 5      motorcycle  16844   3412    212   66710     0.8270  0.6590    0.7335
# 6         bicycle    296    116     48   86718     0.7260  0.5270    0.6107
# 7    autorickshaw   5445    962    352   80419     0.8500  0.7020    0.7689
# 8          animal    396    167     15   86600     0.6780  0.2630    0.3790
# 9   traffic light    289     91     15   86783     0.7130  0.3000    0.4223
# 10   traffic sign   1645     12  11364   74157     0.6730  0.3800    0.4857
# 11        Overall  72420  14758  14758  857022     0.7759  0.5391    0.6278
#
#     Accuracy     FPR     FNR  mAP@0.5  mAP@0.5:0.95
# 0     0.9655  0.0309  0.0622   0.6040        0.3560
# 1     0.9631  0.0355  0.0443   0.6270        0.3860
# 2     0.9619  0.0377  0.0396   0.7310        0.5290
# 3     0.9756  0.0201  0.0945   0.7040        0.5200
# 4     0.9876  0.0088  0.0903   0.7720        0.5980
# 5     0.9584  0.0487  0.0124   0.7150        0.4560
# 6     0.9981  0.0013  0.1395   0.5450        0.3420
# 7     0.9849  0.0118  0.0607   0.7700        0.5680
# 8     0.9979  0.0019  0.0365   0.3300        0.1730
# 9     0.9988  0.0010  0.0493   0.3720        0.1790
# 10    0.8695  0.0002  0.8735   0.4290        0.2480
# 11    0.9692  0.0180  0.1366   0.5999        0.3959

# %%
# ==============================================================
# YOLOv8 Speed Benchmark (H100 / MIG Safe)
# Resolution: 640 x 640
# Batch size: 1
# Metrics:
#   - Pure Inference Time (ms/frame)
#   - Inference FPS
#   - End-to-End Latency (ms/frame)
#   - Latency FPS
#   - Model Parameters (M)
#   - Model File Size (MB)
# ==============================================================

import torch
import cv2
import csv
import os
from pathlib import Path
from ultralytics import YOLO

# -----------------------------
# CONFIGURATION
# -----------------------------
weights = "/workspace/ultralytics/runs/detect/yolov8l_idd_ciou_sgd/weights/best.pt"          # Path to trained YOLOv8 model
img_path = "/workspace/0000240.jpg"      # Any validation image
img_size = 640
batch_size = 1
csv_file = "benchmark_results_v8lciousgd.csv"

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# -----------------------------
# DEVICE INFO
# -----------------------------
print(f"\nUsing device: {device}")
print(f"GPU: {torch.cuda.get_device_name(0)}")
print(f"CUDA Version: {torch.version.cuda}")
print(f"cuDNN Version: {torch.backends.cudnn.version()}\n")

# -----------------------------
# LOAD MODEL
# -----------------------------
model = YOLO(weights).to(device)
model.model.eval()

model_name = Path(weights).stem
model_size_mb = Path(weights).stat().st_size / (1024 ** 2)

params = sum(p.numel() for p in model.model.parameters())
params_million = params / 1e6

print(f"Model: {model_name}")
print(f"Parameters: {params_million:.2f} M")
print(f"Model file size: {model_size_mb:.2f} MB\n")

# ==============================================================
# 1️ PURE INFERENCE SPEED (FORWARD PASS ONLY)
# ==============================================================

dummy_input = torch.randn(
    batch_size, 3, img_size, img_size, device=device
) / 255.0

# Warm-up
for _ in range(10):
    _ = model.model(dummy_input)

torch.cuda.synchronize()

starter = torch.cuda.Event(enable_timing=True)
ender = torch.cuda.Event(enable_timing=True)

n_runs = 100

starter.record()
with torch.inference_mode():
    for _ in range(n_runs):
        _ = model.model(dummy_input)
ender.record()

torch.cuda.synchronize()

inference_time_ms = starter.elapsed_time(ender) / n_runs
inference_fps = 1000 / inference_time_ms

print("=== Pure Inference (Forward Pass Only) ===")
print(f"Inference Time:  {inference_time_ms:.2f} ms/frame")
print(f"Inference Speed: {inference_fps:.2f} FPS @ {img_size}x{img_size}\n")

# ==============================================================
# 2️ END-TO-END LATENCY (PRE + INFER + POST)
# ==============================================================

img = cv2.imread(img_path)
assert img is not None, "Failed to load image."

# Warm-up
for _ in range(5):
    _ = model.predict(
        img, imgsz=img_size, device=device, verbose=False
    )

torch.cuda.synchronize()

starter.record()
for _ in range(30):
    _ = model.predict(
        img, imgsz=img_size, device=device, verbose=False
    )
ender.record()

torch.cuda.synchronize()

latency_ms = starter.elapsed_time(ender) / 30
latency_fps = 1000 / latency_ms

print("=== End-to-End Latency (Full Pipeline) ===")
print(f"Latency:     {latency_ms:.2f} ms/frame")
print(f"Latency FPS:{latency_fps:.2f}\n")

# ==============================================================
# 3️ SAVE RESULTS TO CSV
# ==============================================================

fieldnames = [
    "Model",
    "GPU",
    "Batch_Size",
    "Image_Size",
    "Params_(M)",
    "Model_Size_(MB)",
    "Inference_Time_(ms)",
    "Inference_FPS",
    "Latency_(ms)",
    "Latency_FPS",
]

file_exists = os.path.isfile(csv_file)

with open(csv_file, mode="a", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    if not file_exists:
        writer.writeheader()

    writer.writerow({
        "Model": model_name,
        "GPU": torch.cuda.get_device_name(0),
        "Batch_Size": batch_size,
        "Image_Size": f"{img_size}x{img_size}",
        "Params_(M)": round(params_million, 2),
        "Model_Size_(MB)": round(model_size_mb, 2),
        "Inference_Time_(ms)": round(inference_time_ms, 2),
        "Inference_FPS": round(inference_fps, 2),
        "Latency_(ms)": round(latency_ms, 2),
        "Latency_FPS": round(latency_fps, 2),
    })

print(f"Benchmark results saved to: {csv_file}")

# ==============================================================
# SUMMARY
# ==============================================================
print("\n=== Benchmark Summary ===")
print(f"Model:            {model_name}")
print(f"GPU:              {torch.cuda.get_device_name(0)} (MIG Enabled)")
print(f"Input Resolution: {img_size}x{img_size}")
print(f"Batch Size:       {batch_size}")
print(f"Parameters:       {params_million:.2f} M")
print(f"Model Size:       {model_size_mb:.2f} MB")
print(f"Inference Time:   {inference_time_ms:.2f} ms ({inference_fps:.2f} FPS)")
print(f"Latency:          {latency_ms:.2f} ms ({latency_fps:.2f} FPS)")
print("=============================================================")
# Out:
# Using device: cuda:0
# GPU: NVIDIA H100 80GB HBM3 MIG 3g.40gb
# CUDA Version: 12.6
# cuDNN Version: 90600
#
# Model: best
# Parameters: 43.64 M
# Model file size: 83.60 MB
#
# === Pure Inference (Forward Pass Only) ===
# Inference Time:  5.55 ms/frame
# Inference Speed: 180.07 FPS @ 640x640
#
# === End-to-End Latency (Full Pipeline) ===
# Latency:     7.49 ms/frame
# Latency FPS:133.52
#
# Benchmark results saved to: benchmark_results_v8lciousgd.csv
#
# === Benchmark Summary ===
# Model:            best
# GPU:              NVIDIA H100 80GB HBM3 MIG 3g.40gb (MIG Enabled)
# Input Resolution: 640x640
# Batch Size:       1
# Parameters:       43.64 M
# Model Size:       83.60 MB
# Inference Time:   5.55 ms (180.07 FPS)
# Latency:          7.49 ms (133.52 FPS)
# =============================================================
